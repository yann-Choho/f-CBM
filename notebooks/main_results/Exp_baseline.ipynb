# %%
# --- bootstrap: make src/ importable and run from the repository root ---
import os, sys
from pathlib import Path

ROOT = next(p for p in (Path.cwd(), *Path.cwd().parents)
            if (p / "src" / "path_info.py").exists())
sys.path.insert(0, str(ROOT / "src"))
os.chdir(ROOT)

# %%
# !pip install adjustText

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, Subset
import torch.nn.functional as F
from torchvision import transforms, datasets
from transformers import BlipModel, BlipProcessor
from tqdm import tqdm
import pandas as pd
import os
from sklearn.model_selection import StratifiedKFold
import numpy as np
import glob
from PIL import Image
from sklearn.metrics import f1_score, accuracy_score, classification_report
import re
from functools import lru_cache
import multiprocessing
import mmap
import json

from transformers import BlipModel, BlipProcessor, CLIPModel, CLIPProcessor

# %%
import warnings

warnings.filterwarnings("ignore", category=FutureWarning, module="huggingface_hub.file_download")

os.environ["TOKENIZERS_PARALLELISM"] = "false" # to remove warnings about parallelism :
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# - Avoid using `tokenizers` before the fork if possible
# - Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
from CBM_pipeline import batch_size, device, num_workers, max_len

# %%
# the paper reports results for both backbones: 'clip' and 'clip-large'
backbone = 'clip'

# %% [markdown]
# # Training baseline on N24News

# %%
torch.cuda.empty_cache()

# %%
from CBM_pipeline import run_baseline

history, model = run_baseline(dataset='N24', backbone=backbone, num_epochs=10, contrastive=False, modality='multi', load=False)

# %%
from CBM_pipeline import run_baseline

history, model = run_baseline(dataset='N24', backbone=backbone, num_epochs=10, contrastive=False, modality='text', load=False)

# %%
from CBM_pipeline import run_baseline

history, model = run_baseline(dataset='N24', backbone=backbone, num_epochs=10, contrastive=False, modality='image', load=False)

# %% [markdown]
# # Training baseline on CUB

# %%
torch.cuda.empty_cache()

# %%
from CBM_pipeline import run_baseline

history, model = run_baseline(dataset='CUB', backbone=backbone, num_epochs=10, contrastive=False, modality='multi', load=False)

# %%
from CBM_pipeline import run_baseline

history, model = run_baseline(dataset='CUB', backbone=backbone, num_epochs=10, contrastive=False, modality='text', load=False)

# %%
from CBM_pipeline import run_baseline

history, model = run_baseline(dataset='CUB', backbone=backbone, num_epochs=10, contrastive=False, modality='image', load=False)

# %% [markdown]
# # Training baseline on agnews

# %%
from CBM_pipeline import run_baseline

history, model = run_baseline(dataset='agnews', backbone=backbone, num_epochs=10, contrastive=False, modality='text', load=False)

# %% [markdown]
# # Training baseline on dbpedia

# %%
from CBM_pipeline import run_baseline

history, model = run_baseline(dataset='dbpedia', backbone=backbone, num_epochs=10, contrastive=False, modality='text', load=False)
